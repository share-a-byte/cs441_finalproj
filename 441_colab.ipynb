# %% [markdown]
# <a href="https://colab.research.google.com/github/share-a-byte/cs441_finalproj/blob/master/441_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/share-a-byte/cs441_finalproj.git
# Out:
# Cloning into 'cs441_finalproj'...
# remote: Enumerating objects: 11812, done.
# remote: Counting objects: 100% (1733/1733), done.
# remote: Compressing objects: 100% (1608/1608), done.
# remote: Total 11812 (delta 182), reused 1516 (delta 108), pack-reused 10079 (from 2)
# Receiving objects: 100% (11812/11812), 76.68 MiB | 11.79 MiB/s, done.
# Resolving deltas: 100% (1089/1089), done.
# Updating files: 100% (9893/9893), done.

# %%
# clean up all wav files
# !cd cs441_finalproj/src/video_clipping/ && rm -rf clips

# %%
# !pip install yt-dlp

# %%
# !pip install torchcodec

# %%
# !cd cs441_finalproj/src && python main.py
# Out:
# Streaming output truncated to the last 5000 lines.
# Shifting by 21992
# 132300 221184
# Noise shape: torch.Size([2, 221184]), Audio shape: torch.Size([2, 221184])
# Clip pool filled to capacity!
#
# Shifting by 24247
# 132300 132096
# Noise shape: torch.Size([2, 132096]), Audio shape: torch.Size([2, 132096])
# Clip pool filled to capacity!
#
# Shifting by 17361
# 132300 132096
# Noise shape: torch.Size([2, 132096]), Audio shape: torch.Size([2, 132096])
# Clip pool filled to capacity!
#
# Shifting by 32712
# 132300 220160
# Noise shape: torch.Size([2, 220160]), Audio shape: torch.Size([2, 220160])
# Clip pool filled to capacity!
#
# Shifting by 71524
# 132300 441344
# Noise shape: torch.Size([2, 441344]), Audio shape: torch.Size([2, 441344])
# Clip pool filled to capacity!
#
# Shifting by 87032
# 132300 220160
# Noise shape: torch.Size([2, 220160]), Audio shape: torch.Size([2, 220160])
# Clip pool filled to capacity!
#
# Shifting by 5906
# 132300 132096
# ...
